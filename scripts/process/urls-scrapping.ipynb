# %%
pip install beautifulsoup4

# %%
pip install requests

# %%
pip install lxml

# %%
from bs4 import BeautifulSoup
import requests
import os
import re

def clean_filename(title):
    """Nettoie le titre pour en faire un nom de fichier valide."""
    title = re.sub(r'[\\/*?:"<>|]', "", title)  # Retire les caractères interdits
    title = re.sub(r'\s+', '_', title)           # Remplace les espaces par des underscores
    return title.strip()[:100]                   # Coupe à 100 caractères max

def scrape_page(url):
    """Scrape une page et extrait son titre et son contenu."""
    try:
        HEADERS = {'User-Agent': 'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148'} # Pour éviter l'erreur 403
        response = requests.get(url, headers=HEADERS, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")
        
        title = soup.title.string.strip() if soup.title else "Titre_non_disponible"
        
        article_content = ""
        article_tags = soup.find_all("p", class_=lambda x: x and "article__paragraph" in x.lower())
        if not article_tags:
            article_tags = soup.find_all("p")
        
        for tag in article_tags:
            article_content += tag.get_text(separator=" ", strip=True) + "\n"
        
        if not article_content.strip():
            article_content = "Contenu non disponible"
        
        print(f"Scrapé : {url}\nTitre : {title}\n---\n")
        return title, article_content
    except Exception as e:
        print(f"Erreur lors du scraping de {url} : {e}")
        return None, None

def scrape_from_file(file_path, output_dir):
    """Lit les URLs depuis un fichier et sauvegarde chaque article dans un fichier individuel."""
    try:
        os.makedirs(output_dir, exist_ok=True)  # Crée le dossier s'il n'existe pas
        
        with open(file_path, "r", encoding="utf-8") as file:
            urls = [url.strip() for url in file.readlines() if url.strip()]
        
        for idx, url in enumerate(urls, start=1):
            title, content = scrape_page(url)
            if title and content:
                safe_title = clean_filename(title)
                filename = f"{idx:03d}_{safe_title}.txt"
                filepath = os.path.join(output_dir, filename)
                with open(filepath, "w", encoding="utf-8") as output:
                    output.write(f"{title}\n\n{content}")
    except Exception as e:
        print(f"Erreur lors de l'ouverture du fichier {file_path} : {e}")

# Configuration des fichiers
input_file = "ODT_urls.txt"
output_dir = "articles_fraceinfo"

# Exécution du scraping
scrape_from_file(input_file, output_dir)

print(f"Scraping terminé, articles enregistrés dans le dossier '{output_dir}'")
# Out:
# Scrapé : https://www.franceinfo.fr/monde/palestine/gaza/temoignages-tous-les-gens-a-gaza-ont-espoir-que-trump-augmente-la-pression-dans-l-enclave-les-habitants-s-accrochent-a-l-espoir-d-une-treve-face-a-la-penurie-et-aux-bombardements_7258449.html
# Titre : TEMOIGNAGES. "Tous les gens à Gaza ont espoir que Trump augmente la pression" : dans l'enclave, les habitants s'accrochent à l'espoir d'une trêve face à la pénurie et aux bombardements
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/proche-orient/israel-palestine/offensive-militaire-a-gaza-la-possibilite-de-la-paix-n-a-jamais-ete-aussi-proche-assure-l-ambassadeur-d-israel-en-france_7258416.html
# Titre : Offensive militaire à Gaza : "La possibilité de la paix n'a jamais été aussi proche", assure l'ambassadeur d'Israël en France
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/palestine/gaza/gaza-israel-annonce-le-lancement-d-une-vaste-operation-terrestre_7258491.html
# Titre : Gaza : Israël annonce le lancement d’une “vaste opération terrestre”
# ---
#
# Scrapé : https://www.franceinfo.fr/environnement/pollution/qualite-de-l-eau/pollution-eau-potable/info-franceinfo-scandale-des-eaux-en-bouteille-comment-un-rapport-sanitaire-defavorable-a-nestle-a-ete-modifie-par-l-etat_7257015.html
# Titre : INFO FRANCEINFO. Scandale des eaux en bouteille : comment un rapport sanitaire défavorable à Nestlé a été modifié par l’Etat
# ---
#
# Scrapé : https://www.franceinfo.fr/environnement/pollution/qualite-de-l-eau/scandale-des-eaux-nestle-l-etat-a-dissimule-au-grand-public-cette-fraude-affirme-alexandre-ouizille-rapporteur-de-la-commission-d-enquete_7258452.html
# Titre : Scandale des eaux Nestlé : "L'État a dissimulé au grand public cette fraude", affirme le rapporteur de la commission d’enquête, Alexandre Ouizille
# ---
#
# Scrapé : https://www.franceinfo.fr/politique/bruno-retailleau/reportage-un-vent-d-espoir-pour-la-droite-les-militants-de-bruno-retailleau-s-enthousiasment-apres-sa-nette-victoire-pour-la-presidence-de-lr_7258389.html
# Titre : REPORTAGE. "Un vent d'espoir pour la droite" : les militants de Bruno Retailleau s'enthousiasment après sa nette victoire pour la présidence de LR
# ---
#
# Scrapé : https://www.franceinfo.fr/replay-magazine/franceinfo/l-invite-politique/victoire-de-bruno-retailleau-cela-valide-la-strategie-des-republicains-de-participer-au-gouvernement-explique-philippe-juvin-depute-lr-des-hauts-de-seine_7258464.html
# Titre : Victoire de Bruno Retailleau : "Cela valide la stratégie des Républicains de participer au gouvernement", estime le député Philippe Juvin
# ---
#
# Scrapé : https://www.franceinfo.fr/economie/automobile/airbag-defectueux-l-ufc-que-choisir-porte-plainte-contre-bmw-mercedes-toyota-et-volkswagen-pour-pratiques-commerciales-trompeuses-et-mise-en-danger-de-la-vie-d-autrui_7258494.html
# Titre : Scandale des airbags défectueux : BMW, Mercedes, Toyota et Volkswagen visées par une plainte pour mise en danger de la vie d'autrui
# ---
#
# Scrapé : https://www.franceinfo.fr/economie/sommet-choose-france-la-banque-en-ligne-revolut-annonce-investir-un-milliard-d-euros-en-france_7258515.html
# Titre : Sommet Choose France : la banque en ligne Revolut annonce investir un milliard d'euros en France
# ---
#
# Scrapé : https://www.franceinfo.fr/culture/cinema/festival-de-cannes/festival-de-cannes-2025-du-sacre-de-julia-ducournau-a-l-emergence-d-ari-aster-pourquoi-la-croisette-n-a-plus-horreur-du-film-de-genre_7244979.html
# Titre : Festival de Cannes 2025 : du sacre de Julia Ducournau à l'émergence d'Ari Aster, pourquoi la Croisette n'a plus horreur du film de genre
# ---
#
# Scrapé : https://www.franceinfo.fr/societe/euthanasie/vrai-ou-faux-l-aide-a-mourir-est-elle-vraiment-plus-utilisee-quand-l-euthanasie-est-autorisee_7249668.html
# Titre : VRAI OU FAUX. L'aide à mourir est-elle vraiment plus utilisée quand l'euthanasie est autorisée ?
# ---
#
# Scrapé : https://france3-regions.franceinfo.fr/hauts-de-france/pas-calais/boulogne-mer/un-mort-lors-d-une-tentative-de-traversee-de-la-manche-62-personnes-secourues-3156107.html
# Titre : Un mort lors d'une tentative de traversée de la Manche, 62 personnes secourues
# ---
#
# Scrapé : https://www.franceinfo.fr/replay-radio/le-decryptage-eco/transport-sanitaire-la-securite-sociale-veut-reduire-la-note-des-taxis-qui-se-mobilisent-partout-en-france-pour-protester_7242024.html
# Titre : Transport sanitaire : la sécurité sociale veut réduire la note des taxis qui se mobilisent partout en France pour protester
# ---
#
# Scrapé : https://www.franceinfo.fr/faits-divers/affaire-le-scouarnec/ils-sont-aussi-coupables-que-lui-puisqu-ils-l-ont-laisse-agir-au-proces-le-scouarnec-les-auditions-tres-attendues-de-plusieurs-responsables-des-instances-hospitalieres_7258473.html
# Titre : "Ils sont aussi coupables que lui puisqu'ils l'ont laissé agir" : au procès Le Scouarnec, les auditions très attendues de plusieurs responsables des instances hospitalières
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/usa/joe-biden/l-ancien-president-americain-joe-biden-a-ete-diagnostique-d-une-forme-agressive-d-un-cancer-de-la-prostate_7257321.html
# Titre : L'ancien président américain Joe Biden a été diagnostiqué d'une forme "agressive" d'un cancer de la prostate
# ---
#
# Scrapé : https://france3-regions.franceinfo.fr/provence-alpes-cote-d-azur/alpes-maritimes/cannes/cannes-2025-benicio-del-toro-bill-murray-nicole-kidman-et-de-la-musique-bresilienne-ce-qu-il-faut-retenir-de-ce-18-mai-3155867.html
# Titre : Cannes 2025 : Benicio del Toro, Bill Murray, Nicole Kidman et de la musique brésilienne... Ce qu'il faut retenir de ce 18 mai
# ---
#
# Scrapé : https://www.franceinfo.fr/culture/cinema/festival-de-cannes/festival-de-cannes-2025-raphael-quenard-enflamme-la-croisette-avec-i-love-peru-un-film-personnel-et-dejante_7257123.html
# Titre : Festival de Cannes 2025 : Raphaël Quenard enflamme La Croisette avec "I love Peru", un film personnel et déjanté
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/europe/presidentielle-en-roumanie-les-premiers-sondages-sortis-des-urnes-donnent-le-candidat-pro-europeen-nicusor-dan-devant-son-rival-d-extreme-droite_7257243.html
# Titre : Présidentielle en Roumanie : le candidat pro-européen Nicusor Dan remporte l'élection, devant son rival d'extrême droite George Simion
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/europe/manifestations-en-ukraine/reportage-on-s-adapte-tres-vite-on-n-a-pas-beaucoup-de-temps-les-ukrainiens-tentent-de-rattraper-l-avance-prise-par-les-russes-sur-les-drones-filaires_7256820.html
# Titre : REPORTAGE. "On s'adapte très vite, on n'a pas beaucoup de temps" : les Ukrainiens tentent de rattraper l'avance prise par les Russes sur les drones filaires
# ---
#
# Scrapé : https://www.franceinfo.fr/societe/sdf/plus-de-850-personnes-sans-domicile-fixe-morts-en-2024-selon-le-collectif-les-morts-de-la-rue_7258434.html
# Titre : Plus de 850 personnes sans domicile fixe morts en 2024, selon le Collectif Les Morts de la Rue
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/europe/presidentielle-en-pologne-le-candidat-pro-europeen-legerement-en-tete-du-premier-tour-selon-un-premier-sondage-de-sortie-des-urnes_7257303.html
# Titre : Présidentielle en Pologne : le candidat pro-européen légèrement en tête du premier tour, selon un premier sondage de sortie des urnes
# ---
#
# Scrapé : https://www.franceinfo.fr/roland-garros/programme/roland-garros-2025-a-quelle-heure-et-sur-quelles-chaines-suivre-les-internationaux-de-france-de-tennis-des-qualifications-aux-finales_7247589.html
# Titre : Roland-Garros 2025 : à quelle heure et sur quelles chaines suivre les Internationaux de France de tennis, des qualifications aux finales ?
# ---
#
# Scrapé : https://www.franceinfo.fr/economie/transports/retards-de-vols-les-associations-de-consommateurs-alertent-sur-une-potentielle-revision-du-seuil-d-indemnisation_7233168.html
# Titre : Retards de vols : les associations de consommateurs alertent sur une potentielle révision du seuil d'indemnisation
# ---
#
# Scrapé : https://www.franceinfo.fr/une-information-transparente-franceinfo/transparence-pourquoi-france-televisions-a-t-elle-decide-de-se-lancer-dans-l-identification-systematique-de-ses-images_7218165.html
# Titre : TRANSPARENCE. Pourquoi France Télévisions a-t-elle décidé de se lancer dans l'identification systématique de ses images ?
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/europe/legislatives-au-portugal-courte-victoire-de-la-coalition-de-droite-sortante-selon-un-sondage-de-sortie-des-urnes_7257312.html
# Titre : Législatives au Portugal : courte victoire de la coalition de droite sortante, selon un sondage de sortie des urnes
# ---
#
# Scrapé : https://www.franceinfo.fr/economie/transports/aeroport-de-paris-orly-les-compagnies-appelees-a-supprimer-15-des-vols-lundi-a-cause-d-une-panne-de-controle-aerien_7257333.html
# Titre : Aéroport de Paris-Orly : les compagnies appelées à supprimer 15% des vols lundi à cause d'une panne de contrôle aérien
# ---
#
# Scrapé : https://www.franceinfo.fr/culture/cinema/festival-de-cannes/interview-festival-de-cannes-2025-j-ai-fait-ce-film-parce-que-quand-mon-pere-est-mort-je-n-ai-pas-reussi-a-pleurer-chie-hayakawa-en-course-pour-la-palme-d-or-avec-renoir_7257351.html
# Titre : INTERVIEW. Festival de Cannes 2025 : "J'ai fait ce film parce que quand mon père est mort, je n'ai pas réussi à pleurer", Chie Hayakawa, en course pour la Palme d'or avec "Renoir"
# ---
#
# Scrapé : https://www.franceinfo.fr/monde/europe/manifestations-en-ukraine/reportage-on-s-adapte-tres-vite-on-n-a-pas-beaucoup-de-temps-les-ukrainiens-tentent-de-rattraper-l-avance-prise-par-les-russes-sur-les-drones-filaires_7256820.html
# Titre : REPORTAGE. "On s'adapte très vite, on n'a pas beaucoup de temps" : les Ukrainiens tentent de rattraper l'avance prise par les Russes sur les drones filaires
# ---
#
# Scrapé : https://www.franceinfo.fr/culture/musique/eurovision/eurovision-2025-des-centaines-de-manifestants-a-bale-ville-accueillant-la-competition-pour-s-opposer-a-la-participation-d-israel_7255416.html
# Titre : Eurovision 2025 : des centaines de manifestants défilent à Bâle, ville hôte, pour s'opposer à la participation d'Israël
# ---
#
# Scrapé : https://www.franceinfo.fr/culture/cinema/festival-de-cannes/festival-de-cannes-2025-du-sacre-de-julia-ducournau-a-l-emergence-d-ari-aster-pourquoi-la-croisette-n-a-plus-horreur-du-film-de-genre_7244979.html
# Titre : Festival de Cannes 2025 : du sacre de Julia Ducournau à l'émergence d'Ari Aster, pourquoi la Croisette n'a plus horreur du film de genre
# ---
#
# Scraping terminé, articles enregistrés dans le dossier 'articles_fraceinfo'
